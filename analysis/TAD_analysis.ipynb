# %%
import os
import sys
import glob

import numpy as np
import pandas as pd

# %% [markdown]
# ## Get TAD data
#
# Download, decompress, and import data from Miami

# %%
! mkdir -p ../data/external/tads/
! wget http://dna.cs.miami.edu/TADKB/download/TAD_annotations.tar.gz --directory-prefix=../data/external/tads/
! tar -zxvf ../data/external/tads/TAD_annotations.tar.gz -C ../data/external/tads/
# Out:
# --2020-12-02 21:52:33--  http://dna.cs.miami.edu/TADKB/download/TAD_annotations.tar.gz
# Resolving dna.cs.miami.edu (dna.cs.miami.edu)... 192.31.89.34
# Connecting to dna.cs.miami.edu (dna.cs.miami.edu)|192.31.89.34|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1473379 (1.4M) [application/x-gzip]
# Saving to: ‘../data/external/tads/TAD_annotations.tar.gz.3’
#
# TAD_annotations.tar 100%[===================>]   1.40M  3.27MB/s    in 0.4s
#
# 2020-12-02 21:52:34 (3.27 MB/s) - ‘../data/external/tads/TAD_annotations.tar.gz.3’ saved [1473379/1473379]
#
# TAD_annotations/
# TAD_annotations/TADs/
# TAD_annotations/TADs/HiC_GM12878_DI_10kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_IS_10kb.txt
# TAD_annotations/TADs/HiC_HMEC_DI_10kb.txt
# TAD_annotations/TADs/HiC_ES_IS_10kb.txt
# TAD_annotations/TADs/HiC_HUVEC_DI_10kb.txt
# TAD_annotations/TADs/HiC_NPC_IS_10kb.txt
# TAD_annotations/TADs/HiC_IMR90_DI_10kb.txt
# TAD_annotations/TADs/HiC_CN_IS_10kb.txt
# TAD_annotations/TADs/HiC_K562_DI_10kb.txt
# TAD_annotations/TADs/HiC_KBM7_DI_10kb.txt
# TAD_annotations/TADs/HiC_NHEK_DI_10kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_DI_10kb.txt
# TAD_annotations/TADs/HiC_GM12878_DI_50kb.txt
# TAD_annotations/TADs/HiC_HMEC_DI_50kb.txt
# TAD_annotations/TADs/HiC_HUVEC_DI_50kb.txt
# TAD_annotations/TADs/HiC_IMR90_DI_50kb.txt
# TAD_annotations/TADs/HiC_K562_DI_50kb.txt
# TAD_annotations/TADs/HiC_KBM7_DI_50kb.txt
# TAD_annotations/TADs/HiC_NHEK_DI_50kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_DI_50kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_DI_10kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_DI_50kb.txt
# TAD_annotations/TADs/HiChIP_ES_DI_50kb.txt
# TAD_annotations/TADs/HiChIP_ES_DI_10kb.txt
# TAD_annotations/TADs/SPRITE_ES_DI_10kb.txt
# TAD_annotations/TADs/SPRITE_ES_DI_50kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_DI_50kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_DI_10kb.txt
# TAD_annotations/TADs/HiC_ES_DI_50kb.txt
# TAD_annotations/TADs/HiC_NPC_DI_50kb.txt
# TAD_annotations/TADs/HiC_CN_DI_50kb.txt
# TAD_annotations/TADs/HiC_CN_DI_10kb.txt
# TAD_annotations/TADs/HiC_NPC_DI_10kb.txt
# TAD_annotations/TADs/HiC_ES_DI_10kb.txt
# TAD_annotations/TADs/HiC_GM12878_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_GM12878_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_HMEC_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_HUVEC_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_IMR90_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_K562_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_KBM7_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_NHEK_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_HMEC_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_HUVEC_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_IMR90_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_K562_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_KBM7_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_NHEK_GMAP_10kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_GMAP_10kb.txt
# TAD_annotations/TADs/HiChIP_ES_GMAP_10kb.txt
# TAD_annotations/TADs/SPRITE_ES_GMAP_10kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_GMAP_10kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_GMAP_50kb.txt
# TAD_annotations/TADs/SPRITE_ES_GMAP_50kb.txt
# TAD_annotations/TADs/HiChIP_ES_GMAP_50kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_ES_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_NPC_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_CN_GMAP_50kb.txt
# TAD_annotations/TADs/HiC_CN_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_NPC_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_ES_GMAP_10kb.txt
# TAD_annotations/TADs/HiC_GM12878_IS_50kb.txt
# TAD_annotations/TADs/HiC_HMEC_IS_50kb.txt
# TAD_annotations/TADs/HiC_HUVEC_IS_50kb.txt
# TAD_annotations/TADs/HiC_IMR90_IS_50kb.txt
# TAD_annotations/TADs/HiC_K562_IS_50kb.txt
# TAD_annotations/TADs/HiC_KBM7_IS_50kb.txt
# TAD_annotations/TADs/HiC_NHEK_IS_50kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_IS_50kb.txt
# TAD_annotations/TADs/HiC_CH12-LX_IS_10kb.txt
# TAD_annotations/TADs/HiC_NHEK_IS_10kb.txt
# TAD_annotations/TADs/HiC_KBM7_IS_10kb.txt
# TAD_annotations/TADs/HiC_K562_IS_10kb.txt
# TAD_annotations/TADs/HiC_IMR90_IS_10kb.txt
# TAD_annotations/TADs/HiC_HUVEC_IS_10kb.txt
# TAD_annotations/TADs/HiC_HMEC_IS_10kb.txt
# TAD_annotations/TADs/HiC_GM12878_IS_10kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_IS_10kb.txt
# TAD_annotations/TADs/HiChIP_GM12878_IS_50kb.txt
# TAD_annotations/TADs/HiChIP_ES_IS_50kb.txt
# TAD_annotations/TADs/HiChIP_ES_IS_10kb.txt
# TAD_annotations/TADs/SPRITE_ES_IS_10kb.txt
# TAD_annotations/TADs/SPRITE_ES_IS_50kb.txt
# TAD_annotations/TADs/SPRITE_GM12878_IS_50kb.txt
# TAD_annotations/TADs/HiC_CN_IS_50kb.txt
# TAD_annotations/TADs/HiC_NPC_IS_50kb.txt
# TAD_annotations/TADs/HiC_ES_IS_50kb.txt
# TAD_annotations/readme

# %%
TAD_caller = 'GMAP'
TAD_resolution = 10
TAD_fn = '../data/external/tads/TAD_annotations/TADs/HiC_K562_{}_{}kb.txt' \
           .format(TAD_caller, TAD_resolution)

TAD_data = pd.read_csv(TAD_fn, sep=r"\s+", header=None, names=['chrom','start','end'])

# %%
TAD_data
# Out:
#      chrom      start        end
# 0     chr1     705000    3355000
# 1     chr1    3355000    6735000
# 2     chr1    6735000    7715000
# 3     chr1    7715000    8415000
# 4     chr1    8415000    9645000
# 5     chr1    9645000   11055000
# 6     chr1   11055000   11795000
# 7     chr1   11795000   13765000
# 8     chr1   13765000   14295000
# 9     chr1   14295000   15415000
# 10    chr1   15415000   18895000
# 11    chr1   18895000   20015000
# 12    chr1   20015000   21525000
# 13    chr1   21525000   22375000
# 14    chr1   22375000   23275000
# 15    chr1   23275000   26815000
# 16    chr1   26815000   27255000
# 17    chr1   27255000   29545000
# 18    chr1   29545000   31175000
# 19    chr1   31175000   34075000
# 20    chr1   34075000   35225000
# 21    chr1   35225000   36935000
# 22    chr1   36935000   37875000
# 23    chr1   37875000   38495000
# 24    chr1   38495000   41465000
# 25    chr1   41465000   43625000
# 26    chr1   43625000   45155000
# 27    chr1   45155000   46785000
# 28    chr1   46785000   47625000
# 29    chr1   47625000   47875000
# ...    ...        ...        ...
# 2405  chrX  108675000  109665000
# 2406  chrX  109665000  111025000
# 2407  chrX  111025000  114405000
# 2408  chrX  114405000  114975000
# 2409  chrX  114975000  117415000
# 2410  chrX  117415000  117945000
# 2411  chrX  117945000  119085000
# 2412  chrX  119085000  119925000
# 2413  chrX  119925000  122725000
# 2414  chrX  122725000  123525000
# 2415  chrX  123525000  124235000
# 2416  chrX  124235000  128665000
# 2417  chrX  128665000  129215000
# 2418  chrX  129215000  129415000
# 2419  chrX  129415000  130105000
# 2420  chrX  130105000  130915000
# 2421  chrX  130915000  132865000
# 2422  chrX  132865000  134205000
# 2423  chrX  134205000  137155000
# 2424  chrX  137155000  137825000
# 2425  chrX  137825000  138635000
# 2426  chrX  138635000  139815000
# 2427  chrX  139815000  147125000
# 2428  chrX  147125000  148555000
# 2429  chrX  148555000  149885000
# 2430  chrX  149885000  150295000
# 2431  chrX  150295000  150905000
# 2432  chrX  150905000  153245000
# 2433  chrX  153245000  153785000
# 2434  chrX  153785000  155225000
#
# [2435 rows x 3 columns]

# %% [markdown]
# ## Get CASA peak calls

# %%
! wget https://www.biorxiv.org/content/biorxiv/early/2020/05/12/2020.05.11.078675/DC7/embed/media-7.xlsx --directory-prefix=../data/
! mv ../data/media-7.xlsx ../data/published_peaks.xlsx
# Out:
# --2020-12-02 21:52:34--  https://www.biorxiv.org/content/biorxiv/early/2020/05/12/2020.05.11.078675/DC7/embed/media-7.xlsx
# Resolving www.biorxiv.org (www.biorxiv.org)... 104.18.8.18, 104.18.9.18
# Connecting to www.biorxiv.org (www.biorxiv.org)|104.18.8.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘../data/media-7.xlsx’
#
# media-7.xlsx            [ <=>                ]  29.02K  --.-KB/s    in 0s
#
# 2020-12-02 21:52:35 (107 MB/s) - ‘../data/media-7.xlsx’ saved [29720]

# %%
# Load BioRXiv version
#hcr_peaks = pd.ExcelFile("../data/published_peaks.xlsx").parse(u"Sheet1")
# Load NatGen revisions version
hcr_peaks = pd.ExcelFile("../data/Supplementary Table 5.xlsx").parse(u"Sheet1")

# %%
hcr_peaks
# Out:
# 73   chr8  128059469  128059669             0.489066        PVT1
# 74   chr8  128066469  128066869             0.501163        PVT1
# 75   chr8  128077069  128077269             0.394837        PVT1
#
#    ROPE_threshold  low_coverage
# 0       log(2.00)           NaN
# 1       log(2.00)           NaN
# 2       log(2.00)           NaN
# 3       log(2.00)           NaN
# 4       log(2.00)           NaN
# 5       log(1.60)           NaN
# 6       log(1.60)           NaN
# 7       log(1.60)           NaN
# 8       log(1.60)           NaN
# 9       log(1.60)           NaN
# 10      log(1.60)           NaN
# 11      log(1.60)           NaN
# 12      log(1.60)           NaN
# 13      log(1.60)           NaN
# 14      log(1.60)           NaN
# 15      log(1.60)           NaN
# 16      log(1.60)           NaN
# 17      log(2.00)           0.0
# 18      log(2.00)           0.0
# 19      log(2.00)           0.0
# 20      log(2.00)           0.0
# 21      log(2.00)           0.0
# 22      log(2.00)           0.0
# 23      log(1.20)           0.0
# 24      log(1.20)           0.0
# 25      log(1.20)           0.0
# 26      log(1.20)           0.0
# 27      log(1.20)           0.0
# 28      log(1.20)           0.0
# 29      log(1.20)           0.0
# ..            ...           ...
# 46      log(1.60)           0.0
# 47      log(1.60)           0.0
# 48      log(1.60)           0.0
# 49      log(1.60)           0.0
# 50      log(1.60)           0.0
# 51      log(1.40)           0.0
# 52      log(1.40)           0.0
# 53      log(1.40)           0.0
# 54      log(1.85)           1.0
# 55      log(1.85)           1.0
# 56      log(1.85)           0.0
# 57      log(1.85)           0.0
# 58      log(1.40)           0.0
# 59      log(1.40)           0.0
# 60      log(1.40)           0.0
# 61      log(1.40)           0.0
# 62      log(1.40)           0.0
# 63      log(1.40)           0.0
# 64      log(1.40)           0.0
# 65      log(1.40)           0.0
# 66      log(1.40)           0.0
# 67      log(1.40)           0.0
# 68      log(1.40)           0.0
# 69      log(1.40)           0.0
# 70      log(1.40)           0.0
# 71      log(1.40)           0.0
# 72      log(1.40)           0.0
# 73      log(1.40)           0.0
# 74      log(1.40)           0.0
# 75      log(1.40)           0.0
#
# [76 rows x 7 columns]

# %% [markdown]
# ## Get house GFFs for studied loci

# %%
my_bucket = 'gs://haddath/sgosai/hff/collate_detailed'
my_loci   = ['MEF', 'NMU', 'CD164', 'ATXN', 'GATA', 'LMO2', 'FADS','MYC']
my_gff_files = [ os.path.join(my_bucket,f'{locus}_locus.gff') for locus in my_loci ]
my_gff = pd.concat([ pd.read_csv(fn, sep=r"\s+", header=0) for fn in my_gff_files ], 
                   ignore_index=True).reset_index(drop=True)
# Out:
# /home/sagergosai/miniconda3/envs/casa/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
my_gff
# Out:
#        cdsEnd   cdsStart  chrom  exonCount  \
# 0    88268723   88190051   chr5         13
# 1    88823788   88722603   chr5         11
# 2    55425452   55396189   chr4          3
# 3    55482785   55435414   chr4         23
# 4    55592109   55556556   chr4          6
# 5    55636192   55599145   chr4         10
# 6   108973514  108876174   chr6         17
# 7   109001458  108987543   chr6         10
# 8   109155889  109145221   chr6          8
# 9   109382378  109368850   chr6          6
# 10  109440590  109392825   chr6          8
# 11  109454196  109444190   chr6         24
# 12  109443905  109441121   chr6         10
# 27                                112013347,112022149      ERP29
# 28  112026688,112033232,112039228,112040480,112042...      NAA25
# 29  112125544,112130510,112134737,112135012,112140...     TRAFD1
# 30  112160187,112163041,112163541,112164108,112167...     HECTD4
# 31  111405947,111418118,111446752,111446941,111447...      SH2B3
# 32  48786553,48791090,48791843,48792322,48793171,4...      GATA1
# 33  48802033,48802662,48802870,48803127,48805437,4...      HDAC6
# 34  33084583,33085712,33085894,33086987,33090531,3...      CSTF3
# 35  33256671,33286412,33328509,33337074,33338756,3...      HIPK3
# 36  33542330,33544766,33547763,33551039,33552107,3...  KIAA1549L
# 37  33741441,33747129,33748776,33750538,33751522,3...      FBXO3
# 38                33703009,33717369,33722378,33736381       CD59
# 39  33858575,33864601,33869345,33869709,33881823,3...       LMO2
# 40                         33858575,33864601,33869345       LMO2
# 41  34105616,34112051,34113715,34115822,34118179,3...      NAT10
# 42  34051730,34052420,34071725,34071900,34076235,3...    CAPRIN1
# 43  34150986,34154264,34154700,34159295,34159905,3...      ABTB2
# 44  34438933,34449191,34450987,34452076,34453089,3...        CAT
# 45  34478792,34480771,34482430,34490008,34493478,3...       ELF5
# 46                         34624265,34642627,34646438        EHF
# 47  61802312,61802800,61803031,61803362,61803669,6...      FADS1
# 48  61816255,61837777,61840333,61840623,61848158,6...      FADS2
# 49                                  61792910,61795340       FEN1
# 50  61873525,61875850,61876110,61876358,61876865,6...      FADS3
# 51  126865907,126877671,126926317,127006554,127064047      PCAT1
# 52                                          127079873     PRNCR1
# 53  127289816,127420828,127479082,127479703,127480...      CASC8
# 54            127322182,127339280,127414887,127415442    POU5F1B
# 55                                          127400398      CCAT2
# 56                      127686342,127691789,127733824     CASC11
# 57                      127736593,127738247,127740395        MYC
# 58                                          127946558     TMEM75
# 59  127795798,127890588,127939507,127989161,128096...       PVT1
#
#                   name proteinID strand       transcriptID      txEnd  \
# 0    ENST00000514135.5    E9PCX5      -         uc032vcj.2   88268830
# 1    ENST00000504921.6    Q06413      -         uc003kjj.4   88883464
# 2    ENST00000506198.5    D6RD79      +         uc062wsu.1   55425657
# 3    ENST00000513440.6    O15516      -         uc003hba.4   55546909
# 4    ENST00000295645.9    Q8N4E4      -         uc003hbb.4   55592245
# 5    ENST00000264218.7    P48645      -         uc003hbc.3   55636298
# 6    ENST00000368972.7    Q8NEN0      +         uc011eao.3  108974472
# 7    ENST00000302071.6    Q9Y6P5      -         uc021zdp.2  109008988
# 8    ENST00000521277.5    E5RJH1      +         uc063qmn.1  109158488
# 9   ENST00000310786.10    Q04900      -         uc003pte.6  109382467
# 10   ENST00000521072.6    Q8IXY8      -         uc003ptg.4  109441171
# 11   ENST00000358577.7    Q8TDZ2      -         uc010kdr.4  109455742
# 12   ENST00000258052.8    O60906      +         uc003pti.5  109443919
# 13   ENST00000230122.3    O43167      -         uc003ptl.2  109483237
# 14   ENST00000424296.6    Q5TCS8      -         uc003ptn.2  109691212
# 15   ENST00000368941.1    Q5TCS4      +         uc063qon.1  109743480
# 16  ENST00000335007.10    P36873      -         uc001tru.5  110742891
# 17   ENST00000545036.5    Q8NA47      +         uc010sye.3  110907534
# 18  ENST00000228841.13    Q6IB42      -         uc001try.6  110920600
# 19  ENST00000261726.11    O14529      +         uc001tsa.5  111350554
# 20   ENST00000361483.4    Q8N4B1      -         uc021rdy.1  111369121
# 21   ENST00000377617.8    Q99700      -         uc001tsj.4  111599676
# 22   ENST00000419234.9    Q7Z569      -         uc001tsn.5  111685956
# 23   ENST00000455480.6    Q6JQN1      +         uc009zvx.4  111757094
# 24   ENST00000261733.7    P05091      +         uc001tst.5  111817532
# 25   ENST00000551404.6    Q8IW41      +         uc001tta.5  111893161
# 26   ENST00000552374.7    Q8NCL8      -         uc001ttd.4  112013165
# 27   ENST00000455836.1    P30040      +         uc001ttl.1  112023220
# 28   ENST00000261745.9    Q14CX7      -         uc001ttm.5  112108783
# 29   ENST00000257604.9    O14545      +         uc001tto.4  112153603
# 30   ENST00000550722.5    F8VWT9      -         uc021reb.1  112382092
# 31   ENST00000341259.6    Q9UQQ2      +         uc001tse.3  111451623
# 32   ENST00000376670.8    P15976      +  ENST00000376670.8   48794311
# 33   ENST00000376619.6    Q9UBN7      +  ENST00000376619.6   48824976
# 34   ENST00000323959.9    Q12996      -         uc001muh.5   33161480
# 35   ENST00000525975.5    Q9H422      +         uc031pzm.2   33353568
# 36   ENST00000321505.9    Q6ZVL6      +         uc021qfs.3   33674098
# 37   ENST00000531080.5    Q49AF1      -         uc058afs.1   33753400
# 38   ENST00000642928.1    Q6FHM9      -         uc001muv.6   33736491
# 39   ENST00000257818.3    P25791      -         uc010rem.4   33892076
# 40   ENST00000395833.7    P25791      -         uc001mve.5   33869816
# 41   ENST00000531159.6    Q9H0A0      +         uc010ren.3   34146574
# 42   ENST00000341394.9    Q14444      +         uc001mvh.3   34102610
# 43   ENST00000435224.3    Q8N961      -         uc001mvl.4   34358010
# 44   ENST00000241052.5    P04040      +         uc001mvm.5   34472060
# 45   ENST00000257832.6    Q9UKW6      -         uc001mvp.3   34513800
# 46   ENST00000531728.5    E9PPS9      +         uc058ahv.1   34646771
# 47   ENST00000542506.5       NaN      -                NaN   61815291
# 48  ENST00000257261.10       NaN      +                NaN   61867354
# 49   ENST00000305885.3       NaN      +                NaN   61797238
# 50   ENST00000278829.7       NaN      -                NaN   61891545
# 51   ENST00000644627.1       NaN      +                NaN  127064901
# 52   ENST00000635449.1       NaN      +                NaN  127092600
# 53   ENST00000502082.5       NaN      -                NaN  127482139
# 54   ENST00000645438.1       NaN      +                NaN  127417210
# 55   ENST00000630920.1       NaN      +                NaN  127402150
# 56   ENST00000502463.7       NaN      -                NaN  127733967
# 57   ENST00000613283.2       NaN      +                NaN  127740958
# 58   ENST00000624314.1       NaN      -                NaN  127948723
# 59   ENST00000663059.1       NaN      +                NaN  128101256
#
#       txStart
# 0    88189632
# 1    88717116
# 2    55395956
# 3    55427902
# 4    55556518
# 5    55595230
# 6   108848415
# 7   108986441
# 8   109095109
# 9   109366513
# 10  109390214
# 11  109444061
# 12  109440723
# 13  109462593
# 14  109492855
# 15  109716505
# 16  110719679
# 17  110846959
# 18  110910818
# 19  111034164
# 20  111360650
# 21  111452267
# 22  111642145
# 23  111686075
# 24  111766932
# 25  111842625
# 26  111931297
# 27  112013347
# 28  112026688
# 29  112125544
# 30  112160187
# 31  111405947
# 32   48786553
# 33   48802033
# 34   33084583
# 35   33256671
# 36   33542330
# 37   33741441
# 38   33703009
# 39   33858575
# 40   33858575
# 41   34105616
# 42   34051730
# 43   34150986
# 44   34438933
# 45   34478792
# 46   34624265
# 47   61802312
# 48   61816255
# 49   61792910
# 50   61873525
# 51  126865907
# 52  127079873
# 53  127289816
# 54  127322182
# 55  127400398
# 56  127686342
# 57  127736593
# 58  127946558
# 59  127795798

# %% [markdown]
# ## Quant fraction of CASA peaks in same TAD as promoter

# %%
res_str = 'For gene {}, {}/{} CASA peaks are in the same TAD'

for YFG in hcr_peaks['target_gene'].unique():
    gene_def = my_gff[ my_gff['geneID'] == YFG ].iloc[0]
    promoter = gene_def['txStart'] if gene_def['strand'] == '+' else gene_def['txEnd']
    find_chr = TAD_data['chrom'] == gene_def['chrom']
    find_start=TAD_data['start'] <= promoter
    find_end = TAD_data['end']   >  promoter
    ref_tad  = TAD_data[ find_chr & find_start & find_end ]
    ref_peaks= hcr_peaks[ hcr_peaks['target_gene'] == YFG ]
    find_peak= (ref_peaks['CRE_start'] < ref_tad['end'].item()) & \
               (ref_peaks['CRE_end'] > ref_tad['start'].item())
    print(res_str.format(YFG, sum(find_peak), len(find_peak)))
# Out:
# For gene FADS1, 5/5 CASA peaks are in the same TAD
# For gene FADS2, 4/4 CASA peaks are in the same TAD
# For gene FADS3, 6/6 CASA peaks are in the same TAD
# For gene FEN1, 2/2 CASA peaks are in the same TAD
# For gene GATA1, 3/3 CASA peaks are in the same TAD
# For gene HDAC6, 3/3 CASA peaks are in the same TAD
# For gene NMU, 11/11 CASA peaks are in the same TAD
# For gene LMO2, 6/6 CASA peaks are in the same TAD
# For gene CAPRIN1, 4/4 CASA peaks are in the same TAD
# For gene CAT, 2/2 CASA peaks are in the same TAD
# For gene CD164, 5/5 CASA peaks are in the same TAD
# For gene MEF2C, 3/3 CASA peaks are in the same TAD
# For gene ERP29, 4/4 CASA peaks are in the same TAD
# For gene MYC, 5/5 CASA peaks are in the same TAD
# For gene PVT1, 13/13 CASA peaks are in the same TAD

# %%
res_str = 'For gene {}, {}/{} CASA peaks are in the same TAD'

for YFG in hcr_peaks['target_gene'].unique():
    gene_def = my_gff[ my_gff['geneID'] == YFG ].iloc[0]
    promoter = gene_def['txStart'] if gene_def['strand'] == '+' else gene_def['txEnd']
    find_chr = TAD_data['chrom'] == gene_def['chrom']
    find_start=TAD_data['start'] <= promoter
    find_end = TAD_data['end']   >  promoter
    ref_tad  = TAD_data[ find_chr & find_start & find_end ]
    ref_peaks= hcr_peaks[ hcr_peaks['target_gene'] == YFG ]
    find_peak= (ref_peaks['CRE_start'] < ref_tad['end'].item()) & \
               (ref_peaks['CRE_end'] > ref_tad['start'].item())
    print(res_str.format(YFG, sum(find_peak), len(find_peak)))
    print(ref_tad)
    print(ref_peaks)
# Out:
# For gene FADS1, 5/5 CASA peaks are in the same TAD
#       chrom     start       end
# 1502  chr11  61495000  62655000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 0  chr11   61813200  61813600             0.926668       FADS1      log(2.00)
# 1  chr11   61814000  61818400             4.018398       FADS1      log(2.00)
# 2  chr11   61833100  61835900             4.034463       FADS1      log(2.00)
# 3  chr11   61841200  61842900             2.039930       FADS1      log(2.00)
# 4  chr11   61868900  61871800             1.899701       FADS1      log(2.00)
#
#    low_coverage
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# For gene FADS2, 4/4 CASA peaks are in the same TAD
#       chrom     start       end
# 1502  chr11  61495000  62655000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 5  chr11   61814500  61817200             2.321921       FADS2      log(1.60)
# 6  chr11   61833500  61835900             2.161371       FADS2      log(1.60)
# 7  chr11   61841500  61842400             1.162228       FADS2      log(1.60)
# 8  chr11   61864500  61864800             1.267389       FADS2      log(1.60)
#
#    low_coverage
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# For gene FADS3, 6/6 CASA peaks are in the same TAD
#       chrom     start       end
# 1502  chr11  61495000  62655000
#     chrom  CRE_start   CRE_end  CRE_activity_summit target_gene  \
# 9   chr11   61816500  61817100            -0.614936       FADS3
# 10  chr11   61833800  61835700             1.606421       FADS3
# 11  chr11   61841500  61842900             0.892564       FADS3
# 12  chr11   61870100  61873100            -1.355926       FADS3
# 13  chr11   61890400  61892300             1.947778       FADS3
# 14  chr11   61892600  61893000             0.529552       FADS3
#
#    ROPE_threshold  low_coverage
# 9       log(1.60)           NaN
# 10      log(1.60)           NaN
# 11      log(1.60)           NaN
# 12      log(1.60)           NaN
# 13      log(1.60)           NaN
# 14      log(1.60)           NaN
# For gene FEN1, 2/2 CASA peaks are in the same TAD
#       chrom     start       end
# 1502  chr11  61495000  62655000
#     chrom  CRE_start   CRE_end  CRE_activity_summit target_gene  \
# 15  chr11   61792000  61794000             1.808255        FEN1
# 16  chr11   61796700  61797200             0.831601        FEN1
#
#    ROPE_threshold  low_coverage
# 15      log(1.60)           NaN
# 16      log(1.60)           NaN
# For gene GATA1, 3/3 CASA peaks are in the same TAD
#      chrom     start       end
# 2367  chrX  48415000  49155000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 17  chrX   48782597  48783497             2.231263       GATA1      log(2.00)
# 18  chrX   48786097  48786997             3.708137       GATA1      log(2.00)
# 19  chrX   48800197  48801297             2.398983       GATA1      log(2.00)
#
#     low_coverage
# 17           0.0
# 18           0.0
# 19           0.0
# For gene HDAC6, 3/3 CASA peaks are in the same TAD
#      chrom     start       end
# 2367  chrX  48415000  49155000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 20  chrX   48786297  48786997            -1.425316       HDAC6      log(2.00)
# 21  chrX   48800297  48801097             1.396662       HDAC6      log(2.00)
# 22  chrX   48801697  48802997             2.587553       HDAC6      log(2.00)
#
#     low_coverage
# 20           0.0
# 21           0.0
# 22           0.0
# For gene NMU, 11/11 CASA peaks are in the same TAD
#     chrom     start       end
# 488  chr4  55125000  56195000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 23  chr4   55602941  55606941             0.501966         NMU      log(1.20)
# 24  chr4   55608941  55610941             0.504197         NMU      log(1.20)
# 25  chr4   55611441  55613941             0.424898         NMU      log(1.20)
# 26  chr4   55614441  55616941             0.606963         NMU      log(1.20)
# 27  chr4   55617441  55618441             0.444287         NMU      log(1.20)
# 28  chr4   55624941  55627441             0.479292         NMU      log(1.20)
# 29  chr4   55631941  55633941             0.509253         NMU      log(1.20)
# 30  chr4   55634441  55640941             2.268011         NMU      log(1.20)
# 31  chr4   55666941  55667441             0.246925         NMU      log(1.20)
# 32  chr4   55670441  55671441             0.238360         NMU      log(1.20)
# 33  chr4   55810941  55811941            -0.277619         NMU      log(1.20)
#
#     low_coverage
# 23           0.0
# 24           0.0
# 25           0.0
# 26           0.0
# 27           0.0
# 28           0.0
# 29           0.0
# 30           0.0
# 31           0.0
# 32           0.0
# 33           0.0
# For gene LMO2, 6/6 CASA peaks are in the same TAD
#       chrom     start       end
# 1480  chr11  33825000  34935000
#     chrom  CRE_start   CRE_end  CRE_activity_summit target_gene  \
# 34  chr11   33869368  33870768             1.384246        LMO2
# 35  chr11   33880468  33883368             1.840324        LMO2
# 36  chr11   33937168  33938068             1.212776        LMO2
# 37  chr11   33940268  33943268             2.883669        LMO2
# 38  chr11   33943668  33946568             3.704188        LMO2
# 39  chr11   33947368  33947868             1.720755        LMO2
#
#    ROPE_threshold  low_coverage
# 34      log(2.00)           0.0
# 35      log(2.00)           0.0
# 36      log(2.00)           0.0
# 37      log(2.00)           0.0
# 38      log(2.00)           0.0
# 39      log(2.00)           0.0
# For gene CAPRIN1, 4/4 CASA peaks are in the same TAD
#       chrom     start       end
# 1480  chr11  33825000  34935000
#     chrom  CRE_start   CRE_end  CRE_activity_summit target_gene  \
# 40  chr11   33944871  33945471             0.803765     CAPRIN1
# 41  chr11   34050971  34051471             0.973987     CAPRIN1
# 42  chr11   34051571  34054171             2.064291     CAPRIN1
# 43  chr11   34085871  34086871             1.009272     CAPRIN1
#
#    ROPE_threshold  low_coverage
# 40      log(1.60)           0.0
# 41      log(1.60)           0.0
# 42      log(1.60)           0.0
# 43      log(1.60)           0.0
# For gene CAT, 2/2 CASA peaks are in the same TAD
#       chrom     start       end
# 1480  chr11  33825000  34935000
#     chrom  CRE_start   CRE_end  CRE_activity_summit target_gene  \
# 44  chr11   33944868  33945268             1.214676         CAT
# 45  chr11   34437468  34440568             3.286668         CAT
#
#    ROPE_threshold  low_coverage
# 44      log(2.00)           0.0
# 45      log(2.00)           0.0
# For gene CD164, 5/5 CASA peaks are in the same TAD
#     chrom      start        end
# 812  chr6  108845000  109425000
#    chrom  CRE_start    CRE_end  CRE_activity_summit target_gene  \
# 46  chr6  109236645  109237345             0.346628       CD164
# 47  chr6  109301445  109302345             0.239428       CD164
# 48  chr6  109303145  109306545             3.479773       CD164
# 49  chr6  109308045  109308645            -1.017805       CD164
# 50  chr6  109381245  109382645             1.469593       CD164
#
#    ROPE_threshold  low_coverage
# 46      log(1.60)           0.0
# 47      log(1.60)           0.0
# 48      log(1.60)           0.0
# 49      log(1.60)           0.0
# 50      log(1.60)           0.0
# For gene MEF2C, 3/3 CASA peaks are in the same TAD
#     chrom     start       end
# 651  chr5  87995000  90135000
#    chrom  CRE_start   CRE_end  CRE_activity_summit target_gene ROPE_threshold  \
# 51  chr5   88836814  88837414             0.791826       MEF2C      log(1.40)
# 52  chr5   88882114  88885514             1.384852       MEF2C      log(1.40)
# 53  chr5   89054814  89055614             0.642401       MEF2C      log(1.40)
#
#     low_coverage
# 51           0.0
# 52           0.0
# 53           0.0
# For gene ERP29, 4/4 CASA peaks are in the same TAD
#       chrom      start        end
# 1674  chr12  111775000  112905000
#     chrom  CRE_start    CRE_end  CRE_activity_summit target_gene  \
# 54  chr12  111994126  111994726             1.432891       ERP29
# 55  chr12  111995026  111995626             1.101615       ERP29
# 56  chr12  112005226  112006426            -0.955167       ERP29
# 57  chr12  112012926  112014926             2.433123       ERP29
#
#    ROPE_threshold  low_coverage
# 54      log(1.85)           1.0
# 55      log(1.85)           1.0
# 56      log(1.85)           0.0
# 57      log(1.85)           0.0
# For gene MYC, 5/5 CASA peaks are in the same TAD
#      chrom      start        end
# 1086  chr8  126715000  128725000
#    chrom  CRE_start    CRE_end  CRE_activity_summit target_gene  \
# 58  chr8  127735369  127736269             0.390329         MYC
# 59  chr8  127794569  127795269            -0.505005         MYC
# 60  chr8  127898369  127899769             0.460155         MYC
# 61  chr8  127959469  127961769             1.194111         MYC
# 62  chr8  128044769  128045569             0.503891         MYC
#
#    ROPE_threshold  low_coverage
# 58      log(1.40)           0.0
# 59      log(1.40)           0.0
# 60      log(1.40)           0.0
# 61      log(1.40)           0.0
# 62      log(1.40)           0.0
# For gene PVT1, 13/13 CASA peaks are in the same TAD
#      chrom      start        end
# 1086  chr8  126715000  128725000
#    chrom  CRE_start    CRE_end  CRE_activity_summit target_gene  \
# 63  chr8  127735869  127736569            -0.722192        PVT1
# 64  chr8  127959769  127960269             0.532410        PVT1
# 65  chr8  128044469  128047669             2.078072        PVT1
# 66  chr8  128047869  128051769             1.493444        PVT1
# 67  chr8  128052169  128052369             0.435323        PVT1
# 68  chr8  128053469  128054069             0.590041        PVT1
# 69  chr8  128055769  128056069             0.502262        PVT1
# 70  chr8  128056969  128057369             0.589327        PVT1
# 71  chr8  128057569  128058469             0.592045        PVT1
# 72  chr8  128058869  128059269             0.637313        PVT1
# 73  chr8  128059469  128059669             0.489066        PVT1
# 74  chr8  128066469  128066869             0.501163        PVT1
# 75  chr8  128077069  128077269             0.394837        PVT1
#
#    ROPE_threshold  low_coverage
# 63      log(1.40)           0.0
# 64      log(1.40)           0.0
# 65      log(1.40)           0.0
# 66      log(1.40)           0.0
# 67      log(1.40)           0.0
# 68      log(1.40)           0.0
# 69      log(1.40)           0.0
# 70      log(1.40)           0.0
# 71      log(1.40)           0.0
# 72      log(1.40)           0.0
# 73      log(1.40)           0.0
# 74      log(1.40)           0.0
# 75      log(1.40)           0.0
